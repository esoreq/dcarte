# %%
import numpy as np 
import pandas as pd 
import os
import sys
# This line allows you to clone the repository and skip installing dcarte
sys.path.insert(0, os.path.abspath("/Users/eyalsoreq/github/DCARTE/"))
import dcarte
# This line allows live changes to the imported file 
# %load_ext autoreload
# %autoreload 2

# %%
# %run base.py
# Out:
# Finished Loading door in:                      0.5 seconds
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# File ~/github/DCARTE/examples/base/base.py:192, in <module>
#     184         LocalDataset(dataset_name = dataset,
#     185                      datasets = p_datasets,
#     186                      pipeline = [f'process_{dataset.lower()}'],
#     187                      domain = domain,
#     188                      module = module,
#     189                      dependencies = parent_datasets[dataset])
#     191 if __name__ == "__main__":
# --> 192     create_base_datasets()
#
# File ~/github/DCARTE/examples/base/base.py:182, in create_base_datasets()
#     155 parent_datasets = { 'Doors':[['door','raw']],
#     156                     'Entryway':[['doors','base']],
#     157                     'Habitat':[['environmental','raw'],
#    (...)
#     169                     'Sleep':[['sleep_mat','raw']],
#     170                     'Transitions':[['motion','base']]}
#     173 for dataset in ['Doors',
#     174                 'Entryway',
#     175                 'Habitat',
#    (...)
#     179                 'Sleep',
#     180                 'Transitions']:
# --> 182     p_datasets = {d[0]:dcarte.load(*d) for d in parent_datasets[dataset]}
#     184     LocalDataset(dataset_name = dataset,
#     185                  datasets = p_datasets,
#     186                  pipeline = [f'process_{dataset.lower()}'],
#     187                  domain = domain,
#     188                  module = module,
#     189                  dependencies = parent_datasets[dataset])
#
# File ~/github/DCARTE/examples/base/base.py:182, in <dictcomp>(.0)
#     155 parent_datasets = { 'Doors':[['door','raw']],
#     156                     'Entryway':[['doors','base']],
#     157                     'Habitat':[['environmental','raw'],
#    (...)
#     169                     'Sleep':[['sleep_mat','raw']],
#     170                     'Transitions':[['motion','base']]}
#     173 for dataset in ['Doors',
#     174                 'Entryway',
#     175                 'Habitat',
#    (...)
#     179                 'Sleep',
#     180                 'Transitions']:
# --> 182     p_datasets = {d[0]:dcarte.load(*d) for d in parent_datasets[dataset]}
#     184     LocalDataset(dataset_name = dataset,
#     185                  datasets = p_datasets,
#     186                  pipeline = [f'process_{dataset.lower()}'],
#     187                  domain = domain,
#     188                  module = module,
#     189                  dependencies = parent_datasets[dataset])
#
# File ~/github/DCARTE/dcarte/utils.py:92, in timer.<locals>.wrapper.<locals>.wrapped(*fun_args, **fun_kwargs)
#      90 else:
#      91     prefix = f'Finished {desc} in:'
# ---> 92 out = fun(*fun_args, **fun_kwargs)
#      93 elapsed = time.perf_counter() - start
#      94 dur = f'{np.round(elapsed,1)}'
#
# File ~/github/DCARTE/dcarte/load.py:40, in load(dataset, domain, **kwargs)
#      38 datasets = pd.DataFrame(cfg['domains'])
#      39 if not (datasets == np.array([dataset,domain])).all(axis=1).any():
# ---> 40     raise Exception(f"Sorry, {dataset} is not a registered dataset in {domain} domain in dcarte")
#      42 local_file = f'{data_folder}/{domain}/{dataset}.parquet'
#      43 if path_exists(local_file) and not (dflt['update'] or dflt['reload'] or dflt['reapply']):
#
# Exception: Sorry, doors is not a registered dataset in base domain in dcarte

# %%
%
# Out:
#                   RAW       LEGACY         BASE              PROFILE  \
# 0            Activity  Device_Type        Doors     Activity_Dailies
# 1          Appliances        Doors     Entryway    Activity_Weeklies
# 2         Behavioural     Entryway      Habitat                Light
# 3      Blood_Pressure        Flags      Kitchen   Physiology_Dailies
# 4                Door        Light       Motion  Physiology_Weeklies
# 5           Encounter       Motion   Physiology        Sleep_Dailies
# 6       Environmental  Observation        Sleep       Sleep_Weeklies
# 7               Issue   Physiology  Transitions          Temperature
# 8   Observation_Notes  Temperature
# 9           Procedure    Wellbeing
# 10        Sleep_Event
# 11          Sleep_Mat
# 12        Vital_Signs
#
#         SLEEP_STUDY        LOOKUP     BED_HABITS
# 0           Diurnal  Device_Types  Bed_Occupancy
# 1         Nocturnal         Homes
# 2     Whitings_Tidy      Patients
# 3   Withings_Nights
# 4     Withings_Tidy
# 5
# 6
# 7
# 8
# 9
# 10
# 11
# 12
