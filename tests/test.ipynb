# %%
import os
import sys
sys.path.insert(0, os.path.abspath("/Users/es2814/live/dcarte/"))
import dcarte

# %%
dcarte.download_domain('raw')
# Out:
# THIS FUNCTION MAY TAKE LONG
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# /Users/es2814/live/dcarte/tests/test.ipynb Cell 2 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/Users/es2814/live/dcarte/tests/test.ipynb#W6sZmlsZQ%3D%3D?line=0'>1</a> dcarte.download_domain('raw')
#
# File ~/live/dcarte/dcarte/download.py:31, in download_domain(domain)
#      29 datasets = domains_[[domain.upper()]].replace('',np.nan).dropna()
#      30 for dataset in datasets:
# ---> 31     output.append(load(dataset,domain))
#      33 return output
#
# File ~/live/dcarte/dcarte/utils.py:228, in timer.<locals>.wrapper.<locals>.wrapped(*fun_args, **fun_kwargs)
#     226 else:
#     227     prefix = f'Finished {desc} in:'
# --> 228 out = fun(*fun_args, **fun_kwargs)
#     229 elapsed = time.perf_counter() - start
#     230 dur = f'{np.round(elapsed,1)}'
#
# File ~/live/dcarte/dcarte/load.py:46, in load(dataset, domain, **kwargs)
#      43 last_update = None
#      45 if not (datasets == np.array([dataset,domain])).all(axis=1).any():
# ---> 46     raise Exception(f"Sorry, {dataset} is not a registered dataset in {domain} domain in dcarte")
#      50 local_file = f'{data_folder}{sep}{domain}{sep}{dataset}.parquet'
#      51 if path_exists(local_file):
#
# Exception: Sorry, raw is not a registered dataset in raw domain in dcarte

# %%
import numpy as np 
domain = 'care'
domains = dcarte.domains()
domains[[domain.upper()]].replace('',np.nan).dropna()
# Out:
#                 CARE
# 0          Encounter
# 1              Issue
# 2  Observation_Notes
# 3          Procedure
# 4      Questionnaire

# %%
Sleep_Model = dcarte.load('sleep','base',update=True,delay=0.1)

# %%
dcarte.load('Temperature','base',update=True)
# Out:
# Processing ambient_temperature :**
# Downloading ambient_temperature: 100%|██████████| 1/1 [00:32<00:00, 32.31s/it]
# Finished Loading ambient_temperature in:     103.9 seconds
# Processing device_types :*
# Downloading device_types: 100%|██████████| 1/1 [00:02<00:00,  2.47s/it]
# Finished Loading device_types in:             14.1 seconds
# Finished Loading Temperature in:             168.8 seconds
#                 start_date                        device_type  \
# 0      2019-04-02 15:35:35  Thermometer,_Forehead_thermometer
# 1      2019-04-03 22:49:20  Thermometer,_Forehead_thermometer
# 2      2019-04-04 17:00:40  Thermometer,_Forehead_thermometer
# 3      2019-04-08 12:30:55  Thermometer,_Forehead_thermometer
# 4      2019-04-12 10:37:04  Thermometer,_Forehead_thermometer
# ...                    ...                                ...
# 234655 2023-03-02 08:28:40            Passive_infrared_sensor
# 234656 2023-03-02 08:28:42                        Door_sensor
# 234657 2023-03-02 08:28:43            Passive_infrared_sensor
# 234658 2023-03-02 08:28:55                        Door_sensor
# 234659 2023-03-02 08:28:57                        Door_sensor
#
#                     patient_id                 home_id  \
# 0       EzjmQuxceJzLATdtyUbDn8  JXrs42E92neookBJZYTyZe
# 1       EzjmQuxceJzLATdtyUbDn8  JXrs42E92neookBJZYTyZe
# 2       EzjmQuxceJzLATdtyUbDn8  JXrs42E92neookBJZYTyZe
# 3       EzjmQuxceJzLATdtyUbDn8  JXrs42E92neookBJZYTyZe
# 4       Mhy2uUxJnCtsEZbToCDDEE  8cWNKruugFF78aRVmnSV7h
# ...                        ...                     ...
# 234655  VPf9X4Jn1hh2Y76Jb9Xbuv  B96fARGsBh1y8o5ZnBm9gn
# 234656  DuZ5riT4yDepjB69Xt3t8G  GmKz7e74Fehp535dKanMYq
# 234657  DuZ5riT4yDepjB69Xt3t8G  GmKz7e74Fehp535dKanMYq
# 234658  AupBYL7RJpU4KLUmsWZ7Uz  B5Jvy9bZGj1ZmYPSrAY616
# 234659  6ETMXJgHTXyet2HUohpeYZ  Gh4a4adKsrec37SD8WNjmj
#
#                    location_id location_name   value unit  \
# 0                         None          None  23.752  Cel
# 1                         None          None  20.560  Cel
# 2                         None          None  17.890  Cel
# 3                         None          None  17.299  Cel
# 4                         None          None  19.756  Cel
# ...                        ...           ...     ...  ...
# 234655  RN7iCTnR5uKPBGQshAP518       hallway  16.800  Cel
# 234656  2qXMkY7nvMVmtY7vXnrj2w     back door   9.400  Cel
# 234657  BdokRPGiaXXtVkJsXgmvV2     bathroom1  16.600  Cel
# 234658  WswAnhdFoc16RCGgmhXFKU    front door  14.100  Cel
# 234659  JqNUqRofbRtYfyWfV3Y8By     main door  14.000  Cel
#
#                          source       timezone
# 0       raw_ambient_temperature  Europe/London
# 1       raw_ambient_temperature  Europe/London
# 2       raw_ambient_temperature  Europe/London
# 3       raw_ambient_temperature  Europe/London
# 4       raw_ambient_temperature  Europe/London
# ...                         ...            ...
# 234655  raw_ambient_temperature  Europe/London
# 234656  raw_ambient_temperature  Europe/London
# 234657  raw_ambient_temperature  Europe/London
# 234658  raw_ambient_temperature  Europe/London
# 234659  raw_ambient_temperature  Europe/London
#
# [20372740 rows x 10 columns]

# %%
dcarte.load('transitions','base',update=True)
# Out:
# Finished Loading activity in:                  3.6 seconds
# Finished Loading door in:                      0.8 seconds
# Finished Loading doors in:                     8.1 seconds
# Finished Loading entryway in:                  9.9 seconds
# Processing sleep_mat :*Finished Loading sleep_mat in:                14.5 seconds
# Finished Loading sleep in:                    65.2 seconds
# Finished Loading bed_occupancy in:            66.6 seconds
# Finished Loading motion in:                  110.6 seconds
# Finished Loading transitions in:             162.1 seconds
#                     patient_id          start_date            end_date  \
# 0       2GN1PHeHwRzNYQ7q4Nvg7g 2021-05-14 13:33:44 2021-05-14 13:34:46
# 1       2GN1PHeHwRzNYQ7q4Nvg7g 2021-05-14 13:34:46 2021-05-14 13:34:51
# 2       2GN1PHeHwRzNYQ7q4Nvg7g 2021-05-14 13:34:51 2021-05-14 13:34:52
# 3       2GN1PHeHwRzNYQ7q4Nvg7g 2021-05-14 13:34:52 2021-05-14 13:34:55
# 4       2GN1PHeHwRzNYQ7q4Nvg7g 2021-05-14 13:34:55 2021-05-14 13:34:55
# ...                        ...                 ...                 ...
# 132800   nmj1HefmzzLBRpYNoo11i 2023-03-02 08:17:25 2023-03-02 08:17:39
# 132801   nmj1HefmzzLBRpYNoo11i 2023-03-02 08:17:39 2023-03-02 08:17:54
# 132802   nmj1HefmzzLBRpYNoo11i 2023-03-02 08:17:54 2023-03-02 08:24:06
# 132803   nmj1HefmzzLBRpYNoo11i 2023-03-02 08:24:06 2023-03-02 08:37:10
# 132804   nmj1HefmzzLBRpYNoo11i 2023-03-02 08:37:10 2023-03-02 08:40:11
#
#             source      sink           transition    dur
# 0       Front door  Bathroom  Front door>Bathroom   62.0
# 1         Bathroom   Kitchen     Bathroom>Kitchen    5.0
# 2          Kitchen   Bedroom      Kitchen>Bedroom    1.0
# 3          Bedroom    Lounge       Bedroom>Lounge    3.0
# 4           Lounge   Hallway       Lounge>Hallway    0.0
# ...            ...       ...                  ...    ...
# 132800     Hallway  Bathroom     Hallway>Bathroom   14.0
# 132801    Bathroom   Hallway     Bathroom>Hallway   15.0
# 132802     Hallway    Lounge       Hallway>Lounge  372.0
# 132803      Lounge   Hallway       Lounge>Hallway  784.0
# 132804     Hallway   Hallway      Hallway>Hallway  181.0
#
# [17777098 rows x 7 columns]
